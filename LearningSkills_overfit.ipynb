# %%
# coding: utf-8
import os
import sys

sys.path.append(os.pardir)  # 부모 디렉터리의 파일을 가져올 수 있도록 설정
import numpy as np
import matplotlib.pyplot as plt
from dataset.mnist import load_mnist
from common.multi_layer_net import MultiLayerNet
from common.optimizer import SGD

(x_train, t_train), (x_test, t_test) = load_mnist(normalize=True)

# 오버피팅을  재현하기 위해 학습 데이터 수를 줄임
x_train = x_train[:300]
t_train = t_train[:300]

# weight decay（가중치 감쇠） 설정 =======================
weight_decay_lambda = 0 # weight decay를 사용하지 않을 경우
#weight_decay_lambda = 0.1
# ====================================================

network = MultiLayerNet(input_size=784, hidden_size_list=[100, 100, 100, 100, 100, 100], output_size=10,
                        weight_decay_lambda=weight_decay_lambda)
optimizer = SGD(lr=0.01) # 학습률이 0.01인 SGD로 매개변수 갱신

max_epochs = 201
train_size = x_train.shape[0]
batch_size = 100

train_loss_list = []
train_acc_list = []
test_acc_list = []

iter_per_epoch = max(train_size / batch_size, 1)
epoch_cnt = 0

for i in range(1000000000):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    t_batch = t_train[batch_mask]

    grads = network.gradient(x_batch, t_batch)
    optimizer.update(network.params, grads)

    if i % iter_per_epoch == 0:
        train_acc = network.accuracy(x_train, t_train)
        test_acc = network.accuracy(x_test, t_test)
        train_acc_list.append(train_acc)
        test_acc_list.append(test_acc)

        print("epoch:" + str(epoch_cnt) + ", train acc:" + str(train_acc) + ", test acc:" + str(test_acc))

        epoch_cnt += 1
        if epoch_cnt >= max_epochs:
            break


# 그래프 그리기==========
markers = {'train': 'o', 'test': 's'}
x = np.arange(max_epochs)
plt.plot(x, train_acc_list, marker='o', label='train', markevery=10)
plt.plot(x, test_acc_list, marker='s', label='test', markevery=10)
plt.xlabel("epochs")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
plt.legend(loc='lower right')
plt.show()
# Out:
# epoch:0, train acc:0.09666666666666666, test acc:0.0906
# epoch:1, train acc:0.11666666666666667, test acc:0.0946
# epoch:2, train acc:0.12666666666666668, test acc:0.1042
# epoch:3, train acc:0.16666666666666666, test acc:0.1242
# epoch:4, train acc:0.21333333333333335, test acc:0.1461
# epoch:5, train acc:0.23666666666666666, test acc:0.1591
# epoch:6, train acc:0.2733333333333333, test acc:0.1787
# epoch:7, train acc:0.2966666666666667, test acc:0.2123
# epoch:8, train acc:0.34, test acc:0.2411
# epoch:9, train acc:0.4033333333333333, test acc:0.2712
# epoch:10, train acc:0.43666666666666665, test acc:0.2869
# epoch:11, train acc:0.4633333333333333, test acc:0.3142
# epoch:12, train acc:0.4766666666666667, test acc:0.3306
# epoch:13, train acc:0.49666666666666665, test acc:0.3415
# epoch:14, train acc:0.5166666666666667, test acc:0.3533
# epoch:15, train acc:0.5266666666666666, test acc:0.3635
# epoch:16, train acc:0.5433333333333333, test acc:0.3797
# epoch:17, train acc:0.55, test acc:0.3852
# epoch:18, train acc:0.5533333333333333, test acc:0.3976
# epoch:19, train acc:0.5733333333333334, test acc:0.4095
# epoch:20, train acc:0.5866666666666667, test acc:0.425
# epoch:21, train acc:0.5833333333333334, test acc:0.4281
# epoch:22, train acc:0.5833333333333334, test acc:0.4306
# epoch:23, train acc:0.61, test acc:0.4489
# epoch:24, train acc:0.6266666666666667, test acc:0.4562
# epoch:25, train acc:0.6233333333333333, test acc:0.4635
# epoch:26, train acc:0.6566666666666666, test acc:0.4792
# epoch:27, train acc:0.6666666666666666, test acc:0.4847
# epoch:28, train acc:0.7033333333333334, test acc:0.5074
# epoch:29, train acc:0.74, test acc:0.5158
# epoch:30, train acc:0.7266666666666667, test acc:0.5215
# epoch:31, train acc:0.75, test acc:0.5358
# epoch:32, train acc:0.7566666666666667, test acc:0.5454
# epoch:33, train acc:0.7766666666666666, test acc:0.5553
# epoch:34, train acc:0.7866666666666666, test acc:0.5861
# epoch:35, train acc:0.8066666666666666, test acc:0.5951
# epoch:36, train acc:0.8333333333333334, test acc:0.6032
# epoch:37, train acc:0.8366666666666667, test acc:0.6101
# epoch:38, train acc:0.83, test acc:0.6258
# epoch:39, train acc:0.83, test acc:0.6211
# epoch:40, train acc:0.8566666666666667, test acc:0.6303
# epoch:41, train acc:0.85, test acc:0.6392
# epoch:42, train acc:0.8433333333333334, test acc:0.6378
# epoch:43, train acc:0.8633333333333333, test acc:0.6357
# epoch:44, train acc:0.88, test acc:0.6573
# epoch:45, train acc:0.8666666666666667, test acc:0.6596
# epoch:46, train acc:0.8766666666666667, test acc:0.6661
# epoch:47, train acc:0.8933333333333333, test acc:0.6724
# epoch:48, train acc:0.8933333333333333, test acc:0.6656
# epoch:49, train acc:0.8866666666666667, test acc:0.6636
# epoch:50, train acc:0.9166666666666666, test acc:0.6794
# epoch:51, train acc:0.92, test acc:0.6811
# epoch:52, train acc:0.9266666666666666, test acc:0.6896
# epoch:53, train acc:0.9366666666666666, test acc:0.6965
# epoch:54, train acc:0.9433333333333334, test acc:0.6961
# epoch:55, train acc:0.9366666666666666, test acc:0.6937
# epoch:56, train acc:0.9366666666666666, test acc:0.7036
# epoch:57, train acc:0.9433333333333334, test acc:0.7033
# epoch:58, train acc:0.9433333333333334, test acc:0.7051
# epoch:59, train acc:0.9333333333333333, test acc:0.7085
# epoch:60, train acc:0.9433333333333334, test acc:0.7101
# epoch:61, train acc:0.9366666666666666, test acc:0.709
# epoch:62, train acc:0.95, test acc:0.7138
# epoch:63, train acc:0.9466666666666667, test acc:0.7153
# epoch:64, train acc:0.95, test acc:0.7153
# epoch:65, train acc:0.9466666666666667, test acc:0.7146
# epoch:66, train acc:0.95, test acc:0.7137
# epoch:67, train acc:0.9533333333333334, test acc:0.7178
# epoch:68, train acc:0.9566666666666667, test acc:0.7117
# epoch:69, train acc:0.9533333333333334, test acc:0.7178
# epoch:70, train acc:0.97, test acc:0.7269
# epoch:71, train acc:0.97, test acc:0.7239
# epoch:72, train acc:0.9666666666666667, test acc:0.7243
# epoch:73, train acc:0.9733333333333334, test acc:0.7261
# epoch:74, train acc:0.9733333333333334, test acc:0.7302
# epoch:75, train acc:0.97, test acc:0.7238
# epoch:76, train acc:0.9733333333333334, test acc:0.731
# epoch:77, train acc:0.9766666666666667, test acc:0.7306
# epoch:78, train acc:0.9733333333333334, test acc:0.7318
# epoch:79, train acc:0.97, test acc:0.7243
# epoch:80, train acc:0.9766666666666667, test acc:0.7276
# epoch:81, train acc:0.9766666666666667, test acc:0.7325
# epoch:82, train acc:0.9766666666666667, test acc:0.7335
# epoch:83, train acc:0.98, test acc:0.7379
# epoch:84, train acc:0.9833333333333333, test acc:0.7413
# epoch:85, train acc:0.9833333333333333, test acc:0.7351
# epoch:86, train acc:0.9833333333333333, test acc:0.7361
# epoch:87, train acc:0.9833333333333333, test acc:0.7269
# epoch:88, train acc:0.9833333333333333, test acc:0.7413
# epoch:89, train acc:0.9833333333333333, test acc:0.7413
# epoch:90, train acc:0.98, test acc:0.7369
# epoch:91, train acc:0.9833333333333333, test acc:0.7419
# epoch:92, train acc:0.9833333333333333, test acc:0.7439
# epoch:93, train acc:0.99, test acc:0.7433
# epoch:94, train acc:0.9833333333333333, test acc:0.7445
# epoch:95, train acc:0.9866666666666667, test acc:0.7418
# epoch:96, train acc:0.9833333333333333, test acc:0.7428
# epoch:97, train acc:0.99, test acc:0.7479
# epoch:98, train acc:0.99, test acc:0.7445
# epoch:99, train acc:0.99, test acc:0.7421
# epoch:100, train acc:0.9866666666666667, test acc:0.7478
# epoch:101, train acc:0.99, test acc:0.7438
# epoch:102, train acc:0.99, test acc:0.7487
# epoch:103, train acc:0.99, test acc:0.7465
# epoch:104, train acc:0.9866666666666667, test acc:0.7478
# epoch:105, train acc:0.99, test acc:0.7452
# epoch:106, train acc:0.99, test acc:0.7454
# epoch:107, train acc:0.99, test acc:0.745
# epoch:108, train acc:0.99, test acc:0.746
# epoch:109, train acc:0.99, test acc:0.746
# epoch:110, train acc:0.99, test acc:0.7444
# epoch:111, train acc:0.9933333333333333, test acc:0.7444
# epoch:112, train acc:0.9933333333333333, test acc:0.7467
# epoch:113, train acc:0.9933333333333333, test acc:0.7463
# epoch:114, train acc:0.9933333333333333, test acc:0.7463
# epoch:115, train acc:0.9933333333333333, test acc:0.7456
# epoch:116, train acc:0.9933333333333333, test acc:0.748
# epoch:117, train acc:0.9933333333333333, test acc:0.7502
# epoch:118, train acc:0.9933333333333333, test acc:0.7512
# epoch:119, train acc:0.9933333333333333, test acc:0.7523
# epoch:120, train acc:0.9933333333333333, test acc:0.7517
# epoch:121, train acc:0.9933333333333333, test acc:0.7529
# epoch:122, train acc:0.9933333333333333, test acc:0.7532
# epoch:123, train acc:0.9933333333333333, test acc:0.7501
# epoch:124, train acc:0.9933333333333333, test acc:0.7496
# epoch:125, train acc:0.9933333333333333, test acc:0.7521
# epoch:126, train acc:0.9933333333333333, test acc:0.7534
# epoch:127, train acc:0.9933333333333333, test acc:0.7535
# epoch:128, train acc:0.9933333333333333, test acc:0.7515
# epoch:129, train acc:0.9933333333333333, test acc:0.752
# epoch:130, train acc:0.9933333333333333, test acc:0.7519
# epoch:131, train acc:0.9933333333333333, test acc:0.7527
# epoch:132, train acc:0.9933333333333333, test acc:0.7522
# epoch:133, train acc:0.9933333333333333, test acc:0.7516
# epoch:134, train acc:0.9933333333333333, test acc:0.7548
# epoch:135, train acc:0.9966666666666667, test acc:0.7558
# epoch:136, train acc:0.9966666666666667, test acc:0.7543
# epoch:137, train acc:0.9966666666666667, test acc:0.7581
# epoch:138, train acc:0.9966666666666667, test acc:0.7568
# epoch:139, train acc:0.9933333333333333, test acc:0.7541
# epoch:140, train acc:0.9966666666666667, test acc:0.7567
# epoch:141, train acc:0.9966666666666667, test acc:0.7556
# epoch:142, train acc:1.0, test acc:0.7565
# epoch:143, train acc:1.0, test acc:0.755
# epoch:144, train acc:1.0, test acc:0.7555
# epoch:145, train acc:1.0, test acc:0.7571
# epoch:146, train acc:1.0, test acc:0.7564
# epoch:147, train acc:0.9966666666666667, test acc:0.7564
# epoch:148, train acc:1.0, test acc:0.7553
# epoch:149, train acc:0.9966666666666667, test acc:0.7573
# epoch:150, train acc:0.9966666666666667, test acc:0.7563
# epoch:151, train acc:1.0, test acc:0.7574
# epoch:152, train acc:1.0, test acc:0.7571
# epoch:153, train acc:1.0, test acc:0.7577
# epoch:154, train acc:1.0, test acc:0.759
# epoch:155, train acc:1.0, test acc:0.7593
# epoch:156, train acc:0.9966666666666667, test acc:0.7594
# epoch:157, train acc:1.0, test acc:0.759
# epoch:158, train acc:1.0, test acc:0.7602
# epoch:159, train acc:1.0, test acc:0.7608
# epoch:160, train acc:1.0, test acc:0.7578
# epoch:161, train acc:1.0, test acc:0.7579
# epoch:162, train acc:1.0, test acc:0.7591
# epoch:163, train acc:1.0, test acc:0.7606
# epoch:164, train acc:1.0, test acc:0.7607
# epoch:165, train acc:1.0, test acc:0.7581
# epoch:166, train acc:1.0, test acc:0.7605
# epoch:167, train acc:1.0, test acc:0.7602
# epoch:168, train acc:1.0, test acc:0.7617
# epoch:169, train acc:1.0, test acc:0.7609
# epoch:170, train acc:1.0, test acc:0.7598
# epoch:171, train acc:1.0, test acc:0.7611
# epoch:172, train acc:1.0, test acc:0.7612
# epoch:173, train acc:1.0, test acc:0.7594
# epoch:174, train acc:1.0, test acc:0.7617
# epoch:175, train acc:1.0, test acc:0.7607
# epoch:176, train acc:1.0, test acc:0.7608
# epoch:177, train acc:1.0, test acc:0.7608
# epoch:178, train acc:1.0, test acc:0.7616
# epoch:179, train acc:1.0, test acc:0.7604
# epoch:180, train acc:1.0, test acc:0.7611
# epoch:181, train acc:1.0, test acc:0.7612
# epoch:182, train acc:1.0, test acc:0.7612
# epoch:183, train acc:1.0, test acc:0.7615
# epoch:184, train acc:1.0, test acc:0.762
# epoch:185, train acc:1.0, test acc:0.7619
# epoch:186, train acc:1.0, test acc:0.7612
# epoch:187, train acc:1.0, test acc:0.7607
# epoch:188, train acc:1.0, test acc:0.7593
# epoch:189, train acc:1.0, test acc:0.7613
# epoch:190, train acc:1.0, test acc:0.7615
# epoch:191, train acc:1.0, test acc:0.7611
# epoch:192, train acc:1.0, test acc:0.7628
# epoch:193, train acc:1.0, test acc:0.7598
# epoch:194, train acc:1.0, test acc:0.7598
# epoch:195, train acc:1.0, test acc:0.7614
# epoch:196, train acc:1.0, test acc:0.7617
# epoch:197, train acc:1.0, test acc:0.76
# epoch:198, train acc:1.0, test acc:0.7603
# epoch:199, train acc:1.0, test acc:0.7594
# epoch:200, train acc:1.0, test acc:0.7606
